# %% [markdown]
# # CONTEXT ANALYSIS

# %% [markdown]
# Tweet annotations help understandig contextual information about the Tweets.

# %% [markdown]
# Context annotations are derived from the analysis of a Tweet’s text, they include a domain and entity pairing.

# %% [markdown]
# Running the useful notebooks

# %%
# %run setup.ipynb
# %run Functions_for_text_analysis.ipynb
# %run importing,df_study,corpus.ipynb
# Out:
# C:\Users\39324\anaconda3\lib\site-packages\scipy\sparse\sparsetools.py:21: DeprecationWarning: `scipy.sparse.sparsetools` is deprecated!
# scipy.sparse.sparsetools is a private module for scipy.sparse, and should not be used.
#   _deprecated()
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\39324\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\39324\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# <>:25: DeprecationWarning: invalid escape sequence \S
# C:\Users\39324\AppData\Local\Temp\ipykernel_16872\2979463074.py:25: DeprecationWarning: invalid escape sequence \S
#   p1 = re.sub(pattern='http://\S+|https://\S+',repl= '', string=word)
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\39324\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %% [markdown]
# Creating a list from the column 'context_annotations', appending the string 'no context' if the observations is without a value or with the empty list as value

# %%
la=[]
for i in df['context_annotations']:
    if i=='[]' or pd.isnull(i)==True:
        la.append('No context')
    else:
        x = ast.literal_eval(i)
        la.append(x)
la
# Out:
# ['No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
#  'No context',
# ...

# %% [markdown]
# Create a new list of lists where every list contains 'no context' for observations with no context or the names of the domains of the context.

# %%
la2=[]
for i in la:
    la3=[]
    if i=='No context':
        la3.append(i)
    else:
        for j in range(len(i)):
            la3.append(i[j]['domain']['name'])
    la2.append(la3)
la2
# Out:
# [['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
# ...

# %% [markdown]
# Most common domains in the tweets

# %%
combined_list = [domain for lists in la2 for domain in lists]
counts = Counter(combined_list)
most_common_domains = counts.most_common(30)
most_common_domains
# Out:
# [('Unified Twitter Taxonomy', 72370),
#  ('No context', 49140),
#  ('Ongoing News Story', 27706),
#  ('Person', 11251),
#  ('Brand', 9663),
#  ('Events [Entity Service]', 8893),
#  ('Entities [Entity Service]', 7629),
#  ('Politician', 7420),
#  ('Business Taxonomy', 7274),
#  ('Brand Vertical', 4572),
#  ('Interests and Hobbies Vertical', 3414),
#  ('Interests and Hobbies Category', 3340),
#  ('Interests and Hobbies', 2902),
#  ('Brand Category', 2503),
#  ('News Vertical', 2079),
#  ('TV Shows', 2000),
#  ('Political Body', 1561),
#  ('Sports League', 1115),
#  ('Athlete', 1085),
#  ('Sport', 992),
#  ('Musician', 989),
#  ('Product', 762),
#  ('Cities', 726),
#  ('Sports Team', 608),
#  ('Sports Event', 561),
#  ('Music Genre', 554),
#  ('States', 537),
#  ('Global TV Show', 388),
#  ('Actor', 364),
#  ('Entertainment Personality', 321)]

# %% [markdown]
# Create a new list of lists where every list contains 'no context' for observations with no context or the names of the entities of the context.

# %%
la22=[]
for i in la:
    la33=[]
    if i=='No context':
        la33.append(i)
    else:
        for j in range(len(i)):
            la33.append(i[j]['entity']['name'])
    la22.append(la33)
la22
# Out:
# [['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
#  ['No context'],
# ...

# %% [markdown]
# Most common entities in the tweets

# %%
combined_list2 = [entity for lists in la22 for entity in lists]
counts2 = Counter(combined_list2)
most_common_entities = counts2.most_common(30)
most_common_entities
# Out:
# [('No context', 49140),
#  ('COVID-19', 45505),
#  ('Yoweri Museveni', 10735),
#  ('Politics', 6959),
#  ('COVID-19: Latest news updates from around the world', 6151),
#  ('Political figures', 5897),
#  ('News', 2565),
#  ('Entertainment', 2236),
#  ('Joe Biden', 1925),
#  ('Business & finance', 1771),
#  ('News outlets', 1764),
#  ('Tedros Adhanom Ghebreyesus', 1742),
#  ('Africa', 1679),
#  ('Publisher & News Business', 1657),
#  ('Services', 1569),
#  ('Sports', 1321),
#  ('TV/Movies Related - Entertainment', 1292),
#  ('Soccer', 1256),
#  ('CPG', 1178),
#  ('Entertainment & Leisure Business', 1136),
#  ('Donald Trump', 1082),
#  ('United Nations', 1060),
#  ('Twitter', 1048),
#  ('Government institutions', 1007),
#  ('Financial Services Business', 978),
#  ('Drinks', 973),
#  ('Kenya national news', 968),
#  ('Barack Obama', 959),
#  ('Sports & Fitness Business', 925),
#  ('Technology', 888)]
